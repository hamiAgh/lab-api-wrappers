# %% [markdown]
# ### Instructions
#
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# ### User playlists

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="af61625963bb4d81a1b71c616f46d321",
                                                           client_secret="2bda8485d4654e8e8ddad6cb11ae6c9e"))

# %%
#I'm using one of my playlists

playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1EM1K5bbXwFc3A")
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EM1K5bbXwFc3A/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-11-27T11:43:20Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#        'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#        'id': '6M2wZ9GZgrQXHCFfjv46we',
#        'name': 'Dua Lipa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
# ...

# %%
#function to get the name of the playlist

playlist_id= "37i9dQZF1EM1K5bbXwFc3A"

playlist_1 = sp.playlist(playlist_id)

# Extract the playlist name
playlist_name = playlist_1['name']
playlist_name
# Out:
# 'Your Top Songs 2020'

# %%
playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1EM1K5bbXwFc3A") 

playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EM1K5bbXwFc3A/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-11-27T11:43:20Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#        'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#        'id': '6M2wZ9GZgrQXHCFfjv46we',
#        'name': 'Dua Lipa',
#        'type': 'artist',
#        'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
# ...

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist["total"]
# Out:
# 100

# %%
len(playlist["items"]) #default limitation
# Out:
# 100

# %%
playlist["items"][0]["track"]["name"] #first song in the playlist
# Out:
# 'Physical'

# %% [markdown]
# ### Retrieving Songs of the Playlist

# %%
for i in range(0, len(playlist["items"])):
    print(playlist["items"][i]["track"]["name"])
# Out:
# Physical
# I’m Ready (with Demi Lovato)
# So Am I
# Run Run Run
# Warrior (Stand Up)
# Above the Clouds
# React
# My Way
# Look At Her Now
# Best Life
# Salam
# Mother's Daughter
# Rare
# Power
# Titanium (feat. Sia)
# Big Girl
# My Oh My (feat. DaBaby)
# Just Watch Me Now
# Dance Again
# Smoke & Fire
# Don't Start Now
# Might Not Like Me
# Lose You To Love Me
# Yes Yes I Can
# Everything Is Feelin' Right
# Dang Show
# Ring
# Wide Awake
# Slide Away
# Gonna Be a Good Day
# Vulnerable
# Toranj
# You should be sad
# Is That All There Is?
# Hold On
# You Can't Stop The Girl (From Disney's "Maleficent: Mistress of Evil")
# People You Know
# Ey Sareban
# Bullet Blowz - Original Extended Mix
# Az Tou Tanha Shodam
# Let Me Get Me
# Time Of Our Lives
# Nobahari
# Gole Goldoone Man
# Crowded Room (feat. 6LACK)
# Salt
# Broken & Beautiful
# Man Mast
# Kinda Crazy
# My Life is Going On
# Badass Woman - From The Motion Picture "The Hustle"
# You Need To Calm Down
# Going Harder
# Che Bashad
# ...

# %%
#creating a list of my playlist tracks

tracks_top_songs = []
for i in range(0,len(playlist["items"])):
    title = playlist["items"][i]["track"]["name"]
    tracks_top_songs.append(title)
    
tracks_top_songs
# Out:
# ['Physical',
#  'I’m Ready (with Demi Lovato)',
#  'So Am I',
#  'Run Run Run',
#  'Warrior (Stand Up)',
#  'Above the Clouds',
#  'React',
#  'My Way',
#  'Look At Her Now',
#  'Best Life',
#  'Salam',
#  "Mother's Daughter",
#  'Rare',
#  'Power',
#  'Titanium (feat. Sia)',
#  'Big Girl',
#  'My Oh My (feat. DaBaby)',
#  'Just Watch Me Now',
#  'Dance Again',
#  'Smoke & Fire',
#  "Don't Start Now",
#  'Might Not Like Me',
#  'Lose You To Love Me',
#  'Yes Yes I Can',
#  "Everything Is Feelin' Right",
#  'Dang Show',
#  'Ring',
#  'Wide Awake',
#  'Slide Away',
#  'Gonna Be a Good Day',
#  'Vulnerable',
#  'Toranj',
#  'You should be sad',
#  'Is That All There Is?',
#  'Hold On',
#  'You Can\'t Stop The Girl (From Disney\'s "Maleficent: Mistress of Evil")',
#  'People You Know',
#  'Ey Sareban',
#  'Bullet Blowz - Original Extended Mix',
#  'Az Tou Tanha Shodam',
#  'Let Me Get Me',
#  'Time Of Our Lives',
#  'Nobahari',
#  'Gole Goldoone Man',
#  'Crowded Room (feat. 6LACK)',
# ...

# %%
def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

tracks = get_playlist_tracks("spotify", "12Wbv8sIx84T5uh6iOoJ7V")

# %% [markdown]
# ### Retrieving Information about Artists

# %%
# Getting all the artists

playlist_id= "37i9dQZF1EM1K5bbXwFc3A"


def get_artists_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
artists = get_artists_from_playlist("37i9dQZF1EM1K5bbXwFc3A")
artists
# Out:
# ['Kathryn Ostenberg',
#  'Frizzo',
#  'Rana Farhan',
#  'Rahael Lake',
#  'Ava Max',
#  'Havana Brown',
#  'Denzel Curry',
#  'Sogand',
#  'Kid Cudi',
#  'David Guetta',
#  'Max Oazo',
#  'Halsey',
#  'Zakhmi',
#  'Demi Lovato',
#  'Lizzo',
#  'Shahryar Masrour',
#  'Homayoun Shajarian',
#  'Colbie Caillat',
#  'Katy Perry',
#  'Ali Azimi',
#  'Simin Ghanem',
#  'Taylor Swift',
#  'Survivor',
#  'London Grammar',
#  'Beasts With No Name',
#  'Googoosh',
#  'Mehrshad',
#  'Hidden Citizens',
#  'Mohsen Namjoo',
#  'Ariana Grande',
#  'Mansour',
#  'Faouzia',
#  'Rayelle',
#  'Cristina',
#  'Kendrick Lamar',
#  'Hailee Steinfeld',
#  'Ellie Goulding',
#  'ZAYN',
#  'Selena Gomez',
#  'Miley Cyrus',
#  'Sam Smith',
#  'The Pussycat Dolls',
#  'Camila Cabello',
#  'Brynn Elliott',
#  'Cecilia Krull',
#  'Hayedeh',
#  'Ape Drums',
#  'Camishe',
#  'Dua Lipa',
#  'Meghan Trainor',
#  'Amy Winehouse',
#  'Bebe Rexha',
#  'KOYOTIE',
#  'Kari Kimmel',
#  'Sia',
#  'Lady Bri',
#  'Dang Show',
# ...

# %%
# Getting all the artists IDs

def get_artists_ids_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists_ids = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists_ids.append(artist_info['id'])
            
    return list(set(artists_ids))

# %%
artists_ids = get_artists_ids_from_playlist("37i9dQZF1EM1K5bbXwFc3A")
artists_ids
# Out:
# ['0gDQq5D2rtfEpAIPpuoyq9',
#  '6wPhSqRtPu1UhRCDX5yaDJ',
#  '1CjkBNmWNdarD2yuDDWtoy',
#  '4r63FhuTkUYltbVAg5TQnk',
#  '06HL4z0CvFAxyc27GXpf02',
#  '1l5ca6eEXIW8XHBIWPRnWC',
#  '56oDRnqbIiwx4mymNEv7dS',
#  '3cwMBv6HKE4FHZSXXFiHeb',
#  '1EVWYRr2obCRDoSoD6KSuM',
#  '707cnVfI3ISM4j5uzfTc7J',
#  '1jHQI26XkjY8BHwvDnh9Jw',
#  '47w4VyWVolZiXYnFt0wqr9',
#  '4gzpq5DPGxSnKTe4SA8HAU',
#  '0C8ZW7ezQVs4URX5aX7Kqx',
#  '4jE3X9cADx45YcmBiteecQ',
#  '64M6ah0SkkRsnPGtGiRAbb',
#  '26VFTg2z8YR0cCuwLzESi2',
#  '6aZyMrc4doVtZyKNilOmwu',
#  '6S2OmqARrzebs0tKUEyXyp',
#  '0lK2zNl4j8PI4vse9NgsY1',
#  '2YZyLoL8N0Wb9xBt1NhZWg',
#  '2wY79sveU1sp5g7SokKOiI',
#  '4eVyI1yiHoRjVrxt5y7gGL',
#  '66CXWjxzNUsdJxJ2JdwvnR',
#  '5WCHc16VvzVCmBKH70CYfw',
#  '6fxyWrfmjcbj5d12gXeiNV',
#  '5YGY8feqx7naU7z4HrwZM6',
#  '6qgC7vy3w1gDGHlffriyf2',
#  '44gg6tVRVzjoLVJlF4G3x0',
#  '5Uj3HYkiz1cn32IPHMqhOy',
#  '2fIUlieTjLTaNQUIKHX5B8',
#  '26bcq2nyj5GB7uRr558iQg',
#  '6hGL5amK9JGLOa3PNydScE',
#  '0ypwPd6ZLWkYuNVRnRFor2',
# ...

# %% [markdown]
# ### Getting the audio features from my very cheesy playlist!

# %%
track_ids = [track['track']['id'] for track in tracks]
track_ids
# Out:
# ['0A0eOcimSNRs2EQQlH7FFJ',
#  '0MtVmhAx6CxNuxFIUc6Mj9',
#  '6aUAF8JOd8zEl41B6I18xL',
#  '2vGvPQNnyybJmiqpr1HiKX',
#  '1PuLHwFZoh5qYK89I5YBdZ',
#  '0XqvweqwDQluyCKyK25XqC',
#  '3KkXRkHbMCARz0aVfEt68P',
#  '5m9bm8tBxyhvKv41tMAdnv',
#  '6r5tlCMur8Vngv3n0DzOFl',
#  '3HQdwlovzULm18PjvlA5wz',
#  '1Jte640nBiOWyuD7N0odNZ',
#  '3HfSYACG5O3cio4dpHujWo',
#  '4UdckfJgnMiFzY2leDJ11v',
#  '7w5cxTEzp1rfV3KCy0Bd5N',
#  '2DFRFqWNahKtFD112H2iEZ',
#  '49WL7NYewiv6xPVgroXmKz',
#  '3Ed55g8hCz1GmqRTelIPIW',
#  '5TjAhRtHiLjCrzuOhgk50U',
#  '4f1n0muKxA870NYsPmraLN',
#  '0ytcZAli1HSG5qHNp76y6Y',
#  '78dUBuP4dmw7krQz2yEI97',
#  '0VqU5fPMcFo3iH1aWlDevK',
#  '0WSPIU3Y3bNXsGeKnzSnt1',
#  '1ogk8gkNwRw9iHONH2CAna',
#  '5AGC0c1Hqv2iiUpvvxVexq',
#  '7zfTF24acTKL42XSfzGETi',
#  '4Qq8rERaPWkDuZsvSWR9LL',
#  '2LWW6D1zabtolij6KFXQYm',
#  '0QUiguzo0mWdlBk6Nvujic',
#  '2y0ksBOhMh9hbJRLTNK8jC',
#  '78J9MBkAoqfvyeEpQKJDzD',
#  '73M2Vb5MfZh8iGKudkMtlw',
#  '3nATeGcFdtkhpUrRvgr667',
#  '0pdKRp2sUthTPe7RLWpPqQ',
# ...

# %%
sp.audio_features(track_ids[:100])
# Out:
# [{'danceability': 0.291,
#   'energy': 0.319,
#   'key': 7,
#   'loudness': -10.465,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.791,
#   'instrumentalness': 0.468,
#   'liveness': 0.0692,
#   'valence': 0.038,
#   'tempo': 103.793,
#   'type': 'audio_features',
#   'id': '0A0eOcimSNRs2EQQlH7FFJ',
#   'uri': 'spotify:track:0A0eOcimSNRs2EQQlH7FFJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0A0eOcimSNRs2EQQlH7FFJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0A0eOcimSNRs2EQQlH7FFJ',
#   'duration_ms': 323280,
#   'time_signature': 3},
#  {'danceability': 0.171,
#   'energy': 0.626,
#   'key': 8,
#   'loudness': -8.677,
#   'mode': 1,
#   'speechiness': 0.0486,
#   'acousticness': 0.873,
#   'instrumentalness': 0.0252,
#   'liveness': 0.0681,
#   'valence': 0.457,
#   'tempo': 180.098,
#   'type': 'audio_features',
#   'id': '0MtVmhAx6CxNuxFIUc6Mj9',
#   'uri': 'spotify:track:0MtVmhAx6CxNuxFIUc6Mj9',
# ...

# %%
#converting it to a data frame

import pandas as pd
playlist_audio_feature= pd.json_normalize(sp.audio_features(track_ids[:100]))
playlist_audio_feature
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.291  0.3190    7   -10.465     1       0.0306        0.7910
# 1          0.171  0.6260    8    -8.677     1       0.0486        0.8730
# 2          0.324  0.7760    0    -6.784     1       0.0346        0.1510
# 3          0.627  0.3420    2   -12.833     1       0.0394        0.7000
# 4          0.486  0.7690    1    -5.140     1       0.0341        0.0119
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.498  0.0283    6   -25.021     1       0.0427        0.9490
# 96         0.530  0.4970    9   -13.070     1       0.0294        0.0425
# 97         0.554  0.2260    3   -11.323     1       0.0281        0.8910
# 98         0.601  0.1240    2   -18.301     1       0.0830        0.8020
# 99         0.401  0.5350    0   -11.090     1       0.0407        0.8890
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
data = {
    'Track': tracks_Top_songs,
    'Artist': artists,
    'Artist ID': artists_ids,
    'Track ID': track_ids
}

tracks_artists = pd.DataFrame(data)
tracks_artists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       1 import pandas as pd
#       3 data = {
# ----> 4     'Track': tracks_Top_Songs,
#       5     'Artist': artists,
#       6     'Artist ID': artists_ids,
#       7     'Track ID': track_ids
#       8 }
#      10 tracks_artists = pd.DataFrame(data)
#      11 tracks_artists
#
# NameError: name 'tracks_Top_Songs' is not defined

# %%
len(tracks_top_songs)
# Out:
# 100

# %%
len(track_ids)
# Out:
# 215

# %%
len(artists)
# Out:
# 73

# %%
#len of tracks and artists is not equal so I try to create a df with tracks nd their ids


data = {
    'Track': tracks_top_songs,
    'Track ID': track_ids
}

tracks_df = pd.DataFrame(data)
tracks_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 9
#       1 #len of tracks and artists is not equal so I just create a df with tracks nd their ids
#       4 data = {
#       5     'Track': tracks_top_songs,
#       6     'Track ID': track_ids
#       7 }
# ----> 9 tracks_df = pd.DataFrame(data)
#      10 tracks_df
#
# File ~\Videos\Ananconda\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
# ...

# %%
# I have 215 track ids and 100 tracks so I have to limit the ids to the 100 tracks of my playlist

track_ids_limited = [playlist["items"][i]["track"]["id"] for i in range(0, 100)]

# %%
#I checked the id of a few somngs here and it seems correct
data = {
    'Track': tracks_top_songs,
    'Track ID': track_ids_limited
}

tracks_df = pd.DataFrame(data)
tracks_df
# Out:
#                                       Track                Track ID
# 0                                  Physical  3AzjcOeAmA57TIOr9zF1ZW
# 1              I’m Ready (with Demi Lovato)  1fipvP2zmef6vN2IwXfJhY
# 2                                   So Am I  0uUNN1nSoUx1A4fkDCWDQ7
# 3                               Run Run Run  08KyjbAXbJl0EdtTi7GH3x
# 4                        Warrior (Stand Up)  4IUeuZLyVjYJZj0NQVQCPI
# ..                                      ...                     ...
# 95                                 Shekayat  2UZzcPM7OIRcrlhmbyxV9d
# 96                                  Sixteen  4PkIDTPGedm0enzdvilLNd
# 97  Dusk Till Dawn (feat. Sia) - Radio Edit  1j4kHkkpqZRBwE0A4CN4Yv
# 98                        Harleys In Hawaii  5nCthAh3jt4xKuLJAifAaR
# 99                                Shameless  2ogKhhoMClkFXek7ZgxAhN
#
# [100 rows x 2 columns]
